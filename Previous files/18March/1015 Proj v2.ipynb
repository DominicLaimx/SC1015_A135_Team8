# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("songs_normalize.csv")
print(df.shape)
print("There are ", len(df), " songs in the data set.")
df.head()
# Out:
# (2000, 18)
# There are  2000  songs in the data set.
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %% [markdown]
# There are 14 numerical data types and 4 categorical data types, totalling 18 different data types

# %% [markdown]
# Check for null-values

# %%
df[['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'genre']].isnull().sum()
# Out:
# artist              0
# song                0
# duration_ms         0
# explicit            0
# year                0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# genre               0
# dtype: int64

# %% [markdown]
# No null values in these columns

# %%
###Distribution of songs based on popularity score

# %%
fig,axs = plt.subplots(3,1,figsize=(20,10))
sb.boxplot(x='popularity',data=df,ax=axs[0])
sb.histplot(x='popularity',data=df,ax=axs[1])
sb.violinplot(x='popularity',data=df,ax=axs[2])
# Out:
# <AxesSubplot:xlabel='popularity'>

# %%
##Distribution of data for each variable

# %%
fig,axs = plt.subplots(13,1,figsize=(20,45))
sb.boxplot(x='duration_ms',data=df,ax=axs[0])
sb.boxplot(x='year',data=df,ax=axs[1])
sb.boxplot(x='danceability',data=df,ax=axs[2])
sb.boxplot(x='energy',data=df,ax=axs[3])
sb.boxplot(x='key',data=df,ax=axs[4])
sb.boxplot(x='loudness',data=df,ax=axs[5])
sb.boxplot(x='speechiness',data=df,ax=axs[6])
sb.boxplot(x='acousticness',data=df,ax=axs[7])
sb.boxplot(x='instrumentalness',data=df,ax=axs[8])
sb.boxplot(x='liveness',data=df,ax=axs[9])
sb.boxplot(x='valence',data=df,ax=axs[10])
sb.boxplot(x='tempo',data=df,ax=axs[11])
sb.boxplot(x='mode',data=df,ax=axs[12])
# Out:
# <AxesSubplot:xlabel='mode'>

# %%
fig,axs = plt.subplots(13,1,figsize=(20,45))
sb.violinplot(x='duration_ms',data=df,ax=axs[0])
sb.violinplot(x='year',data=df,ax=axs[1])
sb.violinplot(x='danceability',data=df,ax=axs[2])
sb.violinplot(x='energy',data=df,ax=axs[3])
sb.violinplot(x='key',data=df,ax=axs[4])
sb.violinplot(x='loudness',data=df,ax=axs[5])
sb.violinplot(x='speechiness',data=df,ax=axs[6])
sb.violinplot(x='acousticness',data=df,ax=axs[7])
sb.violinplot(x='instrumentalness',data=df,ax=axs[8])
sb.violinplot(x='liveness',data=df,ax=axs[9])
sb.violinplot(x='valence',data=df,ax=axs[10])
sb.violinplot(x='tempo',data=df,ax=axs[11])
sb.boxplot(x='mode',data=df,ax=axs[12])
# Out:
# <AxesSubplot:xlabel='mode'>

# %%
#Compare each variable's correlation to popularity
# Out:
# <AxesSubplot:>

# %%
sb.heatmap(df[['duration_ms', 'year','mode', 'danceability', 'energy', 'key','popularity']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sb.heatmap(df[['loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','popularity']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
##replacing popularity outliers with median

# %%
newpopularity = pd.DataFrame(df['popularity'])
df['newpopularity'] = df['popularity'].mask(df['popularity'] < 30.5, 65.5)
df['newpopularity'] = df['popularity'].mask(df['popularity'] > 98.5, 65.5)
print(df['newpopularity'])
# Out:
# 0       77
# 1       79
# 2       66
# 3       78
# 4       65
#         ..
# 1995    79
# 1996    78
# 1997    69
# 1998    75
# 1999    85
# Name: newpopularity, Length: 2000, dtype: int64

# %%
sb.heatmap(df[['loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','newpopularity']].corr(),annot=True)
# Out:
# <AxesSubplot:>
